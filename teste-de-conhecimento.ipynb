# %%
import time, sys
acertos = 0
erros = 0

#introdução

print('================= Bem-vindo! ==================')
time.sleep(2)
nome_usuario = input('Qual seu nome? ')
print(f'Olá, {nome_usuario}, testaremos seus conhecimentos em uma área de sua escolha.')
time.sleep(2)

#regras

como_funciona = input('Deseja saber as regras do jogo? s/n ')
time.sleep(1)
if como_funciona == 's':
    print('É simples! você terá apenas 3 tentativas para 7 perguntas. Caso erre três vezes, será desclassificado.')
    print('')
    print('Não se preocupe com letras maiúsculas ou minúsculas. Mas cuidado com os acentos. Boa sorte!')
print('')
time.sleep(1)
print('------------------------------------------------')
print('Abaixo, selecione uma área do conheciemento indicando apenas sua numeração:')
print('------------------------------------------------')

#selecção das áreas do conhecimento

print('[1] ciência')
print('[2] conhecimentos gerais')
selecionado = int(input())

#Ciência---------------------------------------------------------------------------------------

if selecionado == 1:
    time.sleep(1)
    print('================= Brooklyn 1986 ==================')
    time.sleep(2)
    teste = f'Em Bed-Stuy, no Brooklyn, {nome_usuario} é conhecido por seu vasto conhecimento em ciência. Hoje, dia 3 de abril de 1986 acontecerá a final do Quiz. Será que {nome_usuario} levará o prêmio do carro do ano para casa?'
    for i in list(teste):
        print(i, end='')
        sys.stdout.flush()
        time.sleep(0.03)
    print('')
    time.sleep(2)
    print('iniciando perguntas em 3')
    for count in range(2, -1,-1):
        print(count)
        time.sleep(1)
    print('')
    
#primeira_pergunta_ciência
    
    primeira_pergunta = input('1) Qual orgão do corpo humano consome mais energia? ')
    if primeira_pergunta == 'cérebro':
        acertos += 1
        print('')
        print('RESPOSTA CORRETA!')
        print('----------------------------')
    else:
        while primeira_pergunta != 'cérebro':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                primeira_pergunta = input('1) Qual orgão do corpo humano consome mais energia? ')
                if primeira_pergunta == 'cérebro':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
                print('----------------------------')

#segunda_pergunta_ciência
 
    if erros < 3:  
        time.sleep(2)
        segunda_pergunta = input('2) Em que galáxia a terra se encontra? ')
        if segunda_pergunta == 'via láctea':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while segunda_pergunta != 'via láctea':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                segunda_pergunta = input('2) Em que galáxia a terra se encontra? ')
                if segunda_pergunta == 'via láctea':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')
            
#terceira_pergunta_ciência

    if erros < 3:  
        time.sleep(2)
        terceira_pergunta = input('3) Os seres humanos são carnívoros onívoros ou herbívoros? ')
        if terceira_pergunta == 'onívoros':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while terceira_pergunta != 'onívoros':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                terceira_pergunta = input('3) Os seres humanos são carnívoros onívoros ou herbívoros? ')
                if terceira_pergunta == 'onívoros':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')
    
#quarta_pergunta_ciência

    if erros < 3:  
        time.sleep(2)
        quarta_pergunta = input('4) Qual o primeiro elemento da tabela periódica? ')
        if quarta_pergunta == 'hidrogênio':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while quarta_pergunta != 'hidrogênio':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                quarta_pergunta = input('4) Qual o primeiro elemento da tabela periódica? ')
                if quarta_pergunta == 'hidrogênio':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')

#quinta_pergunta_ciência

    if erros < 3:  
        time.sleep(2)
        quinta_pergunta = input('5) Qual nome da substancia que da pigmentação do cabelo, pele e olhos? ')
        if quinta_pergunta == 'melanina':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while quinta_pergunta != 'melanina':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                quinta_pergunta = input('5) Qual nome da substancia que da pigmentação do cabelo, pele e olhos? ')
                if quinta_pergunta == 'melanina':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')

#sexta_pergunta_ciência

    if erros < 3:  
        time.sleep(2)
        sexta_pergunta = input('6) Como é nomeado o evento em que ocorre a explosão de uma estrela? ')
        if sexta_pergunta == 'supernova':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while sexta_pergunta != 'supernova':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                sexta_pergunta = input('6) Como é nomeado o evento em que ocorre a explosão de uma estrela? ')
                if sexta_pergunta == 'supernova':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')
        
#sétima_pergunta_ciência
             
    if erros < 3:  
        time.sleep(2)
        setima_pergunta = input('7) Qual é o nome do único satélite natural da terra? ')
        if setima_pergunta == 'lua':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while setima_pergunta != 'lua':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                setima_pergunta = input('7) Qual nome da substancia que da pigmentação do cabelo, pele e olhos? ')
                if setima_pergunta == 'lua':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')
    
    #================================= final do jogo=================================
    
    if acertos == 7:
        print(f'================= PARABÉNS! {nome_usuario.upper()} ==================')
        time.sleep(2)
        final = f'Você realmente provou que é bom em ciência e acertou todas as perguntas. Poderá receber seu prêmio no final do programa.'
        for i in list(final):
            print(i, end='')
            sys.stdout.flush()
            time.sleep(0.03) 
        time.sleep(2)
        print('')
        print(f'Erros = {erros}')
        time.sleep(1)
        print(f'Acertos = {acertos}')
        time.sleep(2)
        print('Até o próximo campeonato:)')

            
#conhecimentos gerais.................................................................................

if selecionado == 2:
    time.sleep(1)
    print('================= Brooklyn 1986 ==================')
    time.sleep(2)
    teste = f'Em Bed-Stuy, no Brooklyn, {nome_usuario} é conhecido por sua vasta sabedoria em conhecimentos gerais. Hoje, dia 3 de abril de 1986 acontecerá a final do Quiz. Será que {nome_usuario} levará o prêmio do carro do ano para casa?'
    for i in list(teste):
        print(i, end='')
        sys.stdout.flush()
        time.sleep(0.03)
    print('')
    time.sleep(2)
    print('iniciando perguntas em 3')
    for count in range(2, -1,-1):
        print(count)
        time.sleep(1)
    print('')
    
#primeira pergunta_conhecimentos_gereais

    primeira_pergunta = input('1) De quem é a famosa frase “Penso, logo existo”? ')
    if primeira_pergunta == 'descartes':
        acertos += 1
        print('')
        print('RESPOSTA CORRETA!')
        print('----------------------------')
    else:
        while primeira_pergunta != 'descartes':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                primeira_pergunta = input('1) De quem é a famosa frase “Penso, logo existo”? ')
                if primeira_pergunta == 'descartes':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
                print('----------------------------')

    
#segunda_pergunta_conhecimentos_gerais
    
    if erros < 3:  
        time.sleep(2)
        segunda_pergunta = input('2) Qual o menor país do mundo? ')
        if segunda_pergunta == 'vaticano':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while segunda_pergunta != 'vaticano':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                segunda_pergunta = input('2) Qual o menor país do mundo? ')
                if segunda_pergunta == 'vaticano':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')

#terceira_pergunta_conhecimentos_gerais

    if erros < 3:  
        time.sleep(2)
        segunda_pergunta = input('3) Quem pintou o teto da capela sistina? ')
        if segunda_pergunta == 'michelangelo':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while segunda_pergunta != 'michelangelo':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                segunda_pergunta = input('3) Quem pintou o teto da capela sistina? ')
                if segunda_pergunta == 'michelangelo':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')

#quarta_pergunta_conheciemtos_gerais

    if erros < 3:  
        time.sleep(2)
        quarta_pergunta = input('4) Quem viveu, segundo a bíblia, 969 anos? ')
        if quarta_pergunta == 'matusalém':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while quarta_pergunta != 'matusalém':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                quarta_pergunta = input('4) Quem viveu, segundo a bíblia, 969 anos? ')
                if quarta_pergunta == 'matusalém':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')

#quinta_pergunta_conheciemtos_gerais

    if erros < 3:  
        time.sleep(2)
        quinta_pergunta = input('5) Qual o maior animal terrestre? ')
        if quinta_pergunta == 'elefante africano':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while quinta_pergunta != 'elefante africano':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                quinta_pergunta = input('5) Qual o maior animal terrestre? ')
                if quinta_pergunta == 'elefante africano':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')
        
#sexta_pergunta_conheciemtos_gerais

    if erros < 3:  
        time.sleep(2)
        sexta_pergunta = input('6) Qual foi o recurso utilizado inicialmente pelo homem para explicar a origem das coisas? ')
        if sexta_pergunta == 'mitologia':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while sexta_pergunta != 'mitologia':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                sexta_pergunta = input('6) Qual foi o recurso utilizado inicialmente pelo homem para explicar a origem das coisas? ')
                if sexta_pergunta == 'mitologia':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')
        
        
#sétima_pergunta_conheciemtos_gerais

    if erros < 3:  
        time.sleep(2)
        setima_pergunta = input('7) Quantas casas decimais tem o número pi? ')
        if setima_pergunta == 'infinitas':
            acertos += 1
            print('')
            print('RESPOSTA CORRETA!')
            print('----------------------------')
        else:
            while setima_pergunta != 'infinitas':
                erros += 1
                print('')
                if erros == 3:
                    print('')
                    time.sleep(2)
                    print('Suas chances acabaram:( Mais sorte na próxima vez.')
                    print(f'Total de acertos {acertos}, erros {erros}')
                    break
                print('RESPOSTA ERRADA:(')
                setima_pergunta = input('7) Quantas casas decimais tem o número pi? ')
                if setima_pergunta == 'infinitas':
                    acertos += 1
                    print('')
                    print('RESPOSTA CORRETA!')
            print('----------------------------------------------')
            
       #============================== final do jogo ===================================
    
    if acertos == 7:
        print(f'================= PARABÉNS! {nome_usuario.upper()} ==================')
        time.sleep(2)
        final = f'Você realmente provou que é bom em conhecimentos gerais e acertou todas as perguntas. Poderá receber seu prêmio no final do programa.'
        for i in list(final):
            print(i, end='')
            sys.stdout.flush()
            time.sleep(0.03)       
        time.sleep(2)
        print('')
        print(f'Erros = {erros}')
        time.sleep(1)
        print(f'Acertos = {acertos}')
        time.sleep(2)
        print('Até o próximo campeonato:)')
